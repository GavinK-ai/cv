# %%
import os
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
# srcPaths = ('all_dataset/s1',
#             'all_dataset/s10',
#             'all_dataset/s11',
#             'all_dataset/s12',
#             'all_dataset/s13',
#             'all_dataset/s14',
#             'all_dataset/s15',
#             'all_dataset/s16',
#             'all_dataset/s17',
#             'all_dataset/s18',
#             'all_dataset/s19',
#             'all_dataset/s2',
#             'all_dataset/s20',
#             'all_dataset/s21',
#             'all_dataset/s22',
#             'all_dataset/s23',
#             'all_dataset/s24',
#             'all_dataset/s25',
#             'all_dataset/s26',
#             'all_dataset/s27',
#             'all_dataset/s28',
#             'all_dataset/s29',
#             'all_dataset/s3',
#             'all_dataset/s30',
#             'all_dataset/s31',
#             'all_dataset/s32',
#             'all_dataset/s33',
#             'all_dataset/s34',
#             'all_dataset/s35',
#             'all_dataset/s36',
#             'all_dataset/s37',
#             'all_dataset/s38',
#             'all_dataset/s39',
#             'all_dataset/s4',
#             'all_dataset/s40',
#             'all_dataset/s41',
#             'all_dataset/s42',
#             'all_dataset/s43',
#             'all_dataset/s44',
#             'all_dataset/s45',
#             'all_dataset/s46',
#             'all_dataset/s47',
#             'all_dataset/s48',
#             'all_dataset/s49',
#             'all_dataset/s5',
#             'all_dataset/s50',
#             'all_dataset/s51',
#             'all_dataset/s52',
#             'all_dataset/s53',
#             'all_dataset/s54',
#             'all_dataset/s55',
#             'all_dataset/s56',
#             'all_dataset/s57',
#             'all_dataset/s58',
#             'all_dataset/s59',
#             'all_dataset/s6',
#             'all_dataset/s60',
#             'all_dataset/s61',
#             'all_dataset/s62',
#             'all_dataset/s63',
#             'all_dataset/s7',
#             'all_dataset/s8',
#             'all_dataset/s9')

# %%
from os import listdir
from os.path import isfile, join

mypath = ''
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
#srcPath =

# %%
classNames = {'afiq':0, 'azureen':1, 'gavin':2, 'goke':3,  'inamul':4, 'jincheng':5, 'mahmuda':6, 'numan':7, 'saseendran':8}

# %%
imgList = []
labelList = []
labelNameList = []
imageNameList = []
i=1
for srcPath in srcPaths:

    # append all files in srcPath dir into imgList and labelList

    for fname in os.listdir(srcPath):

        

        filePath = os.path.join(srcPath, fname)
        #Read image file
        img = cv.imread(filePath)
        #Resize image
        img = cv.resize(img, [200,200], interpolation=cv.INTER_NEAREST)
        #Convert to gray
        #img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

        # spilt the last text in file name to save as label

        fname_no_ext = os.path.splitext(fname)[0]
        # label = fname_no_ext[-1]
        label = fname_no_ext

        imgList.append(img)
        labelList.append(classNames[label])
        labelNameList.append(label)
        print('pytorch_dataset/'+fname_no_ext+str(i)+'.png')
        imageNameList.append(fname_no_ext+str(i)+'.png')
        cv.imwrite('pytorch_dataset/'+fname_no_ext+str(i)+'.png',img)
    i+=1

    # convert to imgList to numpy

    # images = np.array(imgList, dtype='object')
    # labels = np.array(labelList, dtype='object')
    # labelnames = np.array(labelNameList)
# Out:
# pytorch_dataset/afiq1.png
# pytorch_dataset/azureen1.png
# pytorch_dataset/gavin1.png
# pytorch_dataset/goke1.png
# pytorch_dataset/inamul1.png
# pytorch_dataset/jincheng1.png
# pytorch_dataset/mahmuda1.png
# pytorch_dataset/numan1.png
# pytorch_dataset/saseendran1.png
# pytorch_dataset/afiq2.png
# pytorch_dataset/azureen2.png
# pytorch_dataset/goke2.png
# pytorch_dataset/numan2.png
# pytorch_dataset/afiq3.png
# pytorch_dataset/azureen3.png
# pytorch_dataset/goke3.png
# pytorch_dataset/numan3.png
# pytorch_dataset/afiq4.png
# pytorch_dataset/azureen4.png
# pytorch_dataset/goke4.png
# pytorch_dataset/inamul4.png
# pytorch_dataset/mahmuda4.png
# pytorch_dataset/numan4.png
# pytorch_dataset/saseendran4.png
# pytorch_dataset/afiq5.png
# pytorch_dataset/azureen5.png
# pytorch_dataset/goke5.png
# pytorch_dataset/inamul5.png
# pytorch_dataset/mahmuda5.png
# pytorch_dataset/numan5.png
# pytorch_dataset/saseendran5.png
# pytorch_dataset/afiq6.png
# pytorch_dataset/azureen6.png
# pytorch_dataset/gavin6.png
# pytorch_dataset/goke6.png
# pytorch_dataset/mahmuda6.png
# pytorch_dataset/numan6.png
# pytorch_dataset/saseendran6.png
# pytorch_dataset/afiq7.png
# pytorch_dataset/azureen7.png
# pytorch_dataset/gavin7.png
# pytorch_dataset/goke7.png
# pytorch_dataset/inamul7.png
# pytorch_dataset/jincheng7.png
# pytorch_dataset/mahmuda7.png
# pytorch_dataset/numan7.png
# pytorch_dataset/saseendran7.png
# pytorch_dataset/afiq8.png
# pytorch_dataset/azureen8.png
# pytorch_dataset/goke8.png
# pytorch_dataset/inamul8.png
# pytorch_dataset/mahmuda8.png
# pytorch_dataset/numan8.png
# pytorch_dataset/azureen9.png
# pytorch_dataset/gavin9.png
# pytorch_dataset/goke9.png
# pytorch_dataset/mahmuda9.png
# pytorch_dataset/numan9.png
# pytorch_dataset/afiq10.png
# pytorch_dataset/azureen10.png
# pytorch_dataset/goke10.png
# pytorch_dataset/inamul10.png
# pytorch_dataset/mahmuda10.png
# pytorch_dataset/numan10.png
# pytorch_dataset/azureen11.png
# pytorch_dataset/gavin11.png
# pytorch_dataset/goke11.png
# pytorch_dataset/mahmuda11.png
# pytorch_dataset/numan11.png
# pytorch_dataset/saseendran11.png
# pytorch_dataset/afiq12.png
# pytorch_dataset/azureen12.png
# pytorch_dataset/gavin12.png
# pytorch_dataset/goke12.png
# pytorch_dataset/inamul12.png
# pytorch_dataset/jincheng12.png
# pytorch_dataset/mahmuda12.png
# pytorch_dataset/numan12.png
# pytorch_dataset/saseendran12.png
# pytorch_dataset/gavin13.png
# pytorch_dataset/goke13.png
# pytorch_dataset/mahmuda13.png
# pytorch_dataset/numan13.png
# pytorch_dataset/saseendran13.png
# pytorch_dataset/afiq14.png
# pytorch_dataset/azureen14.png
# pytorch_dataset/goke14.png
# pytorch_dataset/inamul14.png
# pytorch_dataset/numan14.png
# pytorch_dataset/azureen15.png
# pytorch_dataset/goke15.png
# pytorch_dataset/jincheng15.png
# pytorch_dataset/mahmuda15.png
# pytorch_dataset/saseendran15.png
# pytorch_dataset/azureen16.png
# pytorch_dataset/gavin16.png
# pytorch_dataset/goke16.png
# pytorch_dataset/mahmuda16.png
# pytorch_dataset/numan16.png
# pytorch_dataset/azureen17.png
# pytorch_dataset/gavin17.png
# pytorch_dataset/inamul17.png
# pytorch_dataset/mahmuda17.png
# pytorch_dataset/numan17.png
# pytorch_dataset/saseendran17.png
# pytorch_dataset/azureen18.png
# pytorch_dataset/jincheng18.png
# pytorch_dataset/azureen19.png
# pytorch_dataset/gavin19.png
# pytorch_dataset/goke19.png
# pytorch_dataset/jincheng19.png
# pytorch_dataset/mahmuda19.png
# pytorch_dataset/numan19.png
# pytorch_dataset/saseendran19.png
# pytorch_dataset/azureen20.png
# pytorch_dataset/gavin20.png
# pytorch_dataset/inamul20.png
# pytorch_dataset/saseendran20.png
# pytorch_dataset/azureen21.png
# pytorch_dataset/gavin21.png
# pytorch_dataset/goke21.png
# pytorch_dataset/inamul21.png
# pytorch_dataset/jincheng21.png
# pytorch_dataset/numan21.png
# pytorch_dataset/saseendran21.png
# pytorch_dataset/azureen22.png
# pytorch_dataset/gavin22.png
# pytorch_dataset/goke22.png
# pytorch_dataset/inamul22.png
# pytorch_dataset/mahmuda22.png
# pytorch_dataset/numan22.png
# pytorch_dataset/saseendran22.png
# pytorch_dataset/afiq23.png
# pytorch_dataset/azureen23.png
# pytorch_dataset/gavin23.png
# pytorch_dataset/goke23.png
# pytorch_dataset/inamul23.png
# pytorch_dataset/jincheng23.png
# pytorch_dataset/mahmuda23.png
# pytorch_dataset/numan23.png
# pytorch_dataset/saseendran23.png
# pytorch_dataset/azureen24.png
# pytorch_dataset/gavin24.png
# pytorch_dataset/goke24.png
# pytorch_dataset/mahmuda24.png
# pytorch_dataset/numan24.png
# pytorch_dataset/afiq25.png
# pytorch_dataset/azureen25.png
# pytorch_dataset/mahmuda25.png
# pytorch_dataset/afiq26.png
# pytorch_dataset/azureen26.png
# pytorch_dataset/gavin26.png
# pytorch_dataset/goke26.png
# pytorch_dataset/inamul26.png
# pytorch_dataset/jincheng26.png
# pytorch_dataset/mahmuda26.png
# pytorch_dataset/numan26.png
# pytorch_dataset/saseendran26.png
# pytorch_dataset/afiq27.png
# pytorch_dataset/azureen27.png
# pytorch_dataset/gavin27.png
# pytorch_dataset/goke27.png
# pytorch_dataset/inamul27.png
# pytorch_dataset/jincheng27.png
# pytorch_dataset/mahmuda27.png
# pytorch_dataset/numan27.png
# pytorch_dataset/saseendran27.png
# pytorch_dataset/afiq28.png
# pytorch_dataset/azureen28.png
# pytorch_dataset/gavin28.png
# pytorch_dataset/inamul28.png
# pytorch_dataset/jincheng28.png
# pytorch_dataset/mahmuda28.png
# pytorch_dataset/numan28.png
# pytorch_dataset/saseendran28.png
# pytorch_dataset/afiq29.png
# pytorch_dataset/azureen29.png
# pytorch_dataset/gavin29.png
# pytorch_dataset/goke29.png
# pytorch_dataset/inamul29.png
# pytorch_dataset/jincheng29.png
# pytorch_dataset/mahmuda29.png
# pytorch_dataset/numan29.png
# pytorch_dataset/saseendran29.png
# pytorch_dataset/afiq30.png
# pytorch_dataset/azureen30.png
# pytorch_dataset/mahmuda30.png
# pytorch_dataset/afiq31.png
# pytorch_dataset/azureen31.png
# pytorch_dataset/gavin31.png
# pytorch_dataset/goke31.png
# pytorch_dataset/inamul31.png
# pytorch_dataset/jincheng31.png
# pytorch_dataset/mahmuda31.png
# pytorch_dataset/numan31.png
# pytorch_dataset/saseendran31.png
# pytorch_dataset/afiq32.png
# pytorch_dataset/azureen32.png
# pytorch_dataset/gavin32.png
# pytorch_dataset/goke32.png
# pytorch_dataset/inamul32.png
# pytorch_dataset/jincheng32.png
# pytorch_dataset/mahmuda32.png
# pytorch_dataset/numan32.png
# pytorch_dataset/saseendran32.png
# pytorch_dataset/afiq33.png
# pytorch_dataset/azureen33.png
# pytorch_dataset/gavin33.png
# pytorch_dataset/goke33.png
# pytorch_dataset/inamul33.png
# pytorch_dataset/mahmuda33.png
# pytorch_dataset/numan33.png
# pytorch_dataset/afiq34.png
# pytorch_dataset/azureen34.png
# pytorch_dataset/gavin34.png
# pytorch_dataset/goke34.png
# pytorch_dataset/inamul34.png
# pytorch_dataset/jincheng34.png
# pytorch_dataset/mahmuda34.png
# pytorch_dataset/numan34.png
# pytorch_dataset/saseendran34.png
# pytorch_dataset/afiq35.png
# pytorch_dataset/gavin35.png
# pytorch_dataset/goke35.png
# pytorch_dataset/saseendran35.png
# pytorch_dataset/afiq36.png
# pytorch_dataset/azureen36.png
# pytorch_dataset/gavin36.png
# pytorch_dataset/goke36.png
# pytorch_dataset/inamul36.png
# pytorch_dataset/jincheng36.png
# pytorch_dataset/mahmuda36.png
# pytorch_dataset/numan36.png
# pytorch_dataset/saseendran36.png
# pytorch_dataset/afiq37.png
# pytorch_dataset/azureen37.png
# pytorch_dataset/gavin37.png
# pytorch_dataset/goke37.png
# pytorch_dataset/mahmuda37.png
# pytorch_dataset/numan37.png
# pytorch_dataset/saseendran37.png
# pytorch_dataset/afiq38.png
# pytorch_dataset/azureen38.png
# pytorch_dataset/gavin38.png
# pytorch_dataset/goke38.png
# pytorch_dataset/mahmuda38.png
# pytorch_dataset/numan38.png
# pytorch_dataset/saseendran38.png
# pytorch_dataset/afiq39.png
# pytorch_dataset/azureen39.png
# pytorch_dataset/gavin39.png
# pytorch_dataset/goke39.png
# pytorch_dataset/mahmuda39.png
# pytorch_dataset/numan39.png
# pytorch_dataset/saseendran39.png
# pytorch_dataset/afiq40.png
# pytorch_dataset/azureen40.png
# pytorch_dataset/gavin40.png
# pytorch_dataset/goke40.png
# pytorch_dataset/mahmuda40.png
# pytorch_dataset/numan40.png
# pytorch_dataset/saseendran40.png
# pytorch_dataset/afiq41.png
# pytorch_dataset/azureen41.png
# pytorch_dataset/gavin41.png
# pytorch_dataset/goke41.png
# pytorch_dataset/mahmuda41.png
# pytorch_dataset/numan41.png
# pytorch_dataset/saseendran41.png
# pytorch_dataset/afiq42.png
# pytorch_dataset/azureen42.png
# pytorch_dataset/gavin42.png
# pytorch_dataset/goke42.png
# pytorch_dataset/goke42.png
# pytorch_dataset/mahmuda42.png
# pytorch_dataset/numan42.png
# pytorch_dataset/saseendran42.png
# pytorch_dataset/afiq43.png
# pytorch_dataset/azureen43.png
# pytorch_dataset/gavin43.png
# pytorch_dataset/goke43.png
# pytorch_dataset/mahmuda43.png
# pytorch_dataset/numan43.png
# pytorch_dataset/saseendran43.png
# pytorch_dataset/afiq44.png
# pytorch_dataset/azureen44.png
# pytorch_dataset/gavin44.png
# pytorch_dataset/goke44.png
# pytorch_dataset/mahmuda44.png
# pytorch_dataset/numan44.png
# pytorch_dataset/saseendran44.png
# pytorch_dataset/afiq45.png
# pytorch_dataset/azureen45.png
# pytorch_dataset/goke45.png
# pytorch_dataset/jincheng45.png
# pytorch_dataset/mahmuda45.png
# pytorch_dataset/numan45.png
# pytorch_dataset/saseendran45.png
# pytorch_dataset/afiq46.png
# pytorch_dataset/azureen46.png
# pytorch_dataset/gavin46.png
# pytorch_dataset/goke46.png
# pytorch_dataset/inamul46.png
# pytorch_dataset/jincheng46.png
# pytorch_dataset/mahmuda46.png
# pytorch_dataset/numan46.png
# pytorch_dataset/saseendran46.png
# pytorch_dataset/afiq47.png
# pytorch_dataset/azureen47.png
# pytorch_dataset/goke47.png
# pytorch_dataset/inamul47.png
# pytorch_dataset/mahmuda47.png
# pytorch_dataset/numan47.png
# pytorch_dataset/afiq48.png
# pytorch_dataset/azureen48.png
# pytorch_dataset/gavin48.png
# pytorch_dataset/goke48.png
# pytorch_dataset/inamul48.png
# pytorch_dataset/jincheng48.png
# pytorch_dataset/mahmuda48.png
# pytorch_dataset/numan48.png
# pytorch_dataset/saseendran48.png
# pytorch_dataset/afiq49.png
# pytorch_dataset/azureen49.png
# pytorch_dataset/gavin49.png
# pytorch_dataset/goke49.png
# pytorch_dataset/inamul49.png
# pytorch_dataset/jincheng49.png
# pytorch_dataset/mahmuda49.png
# pytorch_dataset/numan49.png
# pytorch_dataset/saseendran49.png
# pytorch_dataset/afiq50.png
# pytorch_dataset/azureen50.png
# pytorch_dataset/goke50.png
# pytorch_dataset/inamul50.png
# pytorch_dataset/mahmuda50.png
# pytorch_dataset/numan50.png
# pytorch_dataset/afiq51.png
# pytorch_dataset/azureen51.png
# pytorch_dataset/gavin51.png
# pytorch_dataset/goke51.png
# pytorch_dataset/inamul51.png
# pytorch_dataset/jincheng51.png
# pytorch_dataset/mahmuda51.png
# pytorch_dataset/numan51.png
# pytorch_dataset/saseendran51.png
# pytorch_dataset/azureen52.png
# pytorch_dataset/gavin52.png
# pytorch_dataset/inamul52.png
# pytorch_dataset/mahmuda52.png
# pytorch_dataset/numan52.png
# pytorch_dataset/saseendran52.png
# pytorch_dataset/azureen53.png
# pytorch_dataset/gavin53.png
# pytorch_dataset/goke53.png
# pytorch_dataset/inamul53.png
# pytorch_dataset/jincheng53.png
# pytorch_dataset/mahmuda53.png
# pytorch_dataset/numan53.png
# pytorch_dataset/afiq54.png
# pytorch_dataset/azureen54.png
# pytorch_dataset/inamul54.png
# pytorch_dataset/jincheng54.png
# pytorch_dataset/mahmuda54.png
# pytorch_dataset/numan54.png
# pytorch_dataset/saseendran54.png
# pytorch_dataset/azureen55.png
# pytorch_dataset/gavin55.png
# pytorch_dataset/goke55.png
# pytorch_dataset/mahmuda55.png
# pytorch_dataset/numan55.png
# pytorch_dataset/afiq56.png
# pytorch_dataset/azureen56.png
# pytorch_dataset/gavin56.png
# pytorch_dataset/goke56.png
# pytorch_dataset/inamul56.png
# pytorch_dataset/jincheng56.png
# pytorch_dataset/mahmuda56.png
# pytorch_dataset/numan56.png
# pytorch_dataset/saseendran56.png
# pytorch_dataset/afiq57.png
# pytorch_dataset/azureen57.png
# pytorch_dataset/gavin57.png
# pytorch_dataset/goke57.png
# pytorch_dataset/inamul57.png
# pytorch_dataset/jincheng57.png
# pytorch_dataset/mahmuda57.png
# pytorch_dataset/numan57.png
# pytorch_dataset/saseendran57.png
# pytorch_dataset/afiq58.png
# pytorch_dataset/azureen58.png
# pytorch_dataset/gavin58.png
# pytorch_dataset/goke58.png
# pytorch_dataset/inamul58.png
# pytorch_dataset/jincheng58.png
# pytorch_dataset/mahmuda58.png
# pytorch_dataset/numan58.png
# pytorch_dataset/saseendran58.png
# pytorch_dataset/afiq59.png
# pytorch_dataset/azureen59.png
# pytorch_dataset/gavin59.png
# pytorch_dataset/goke59.png
# pytorch_dataset/inamul59.png
# pytorch_dataset/jincheng59.png
# pytorch_dataset/mahmuda59.png
# pytorch_dataset/saseendran59.png
# pytorch_dataset/afiq60.png
# pytorch_dataset/azureen60.png
# pytorch_dataset/gavin60.png
# pytorch_dataset/goke60.png
# pytorch_dataset/inamul60.png
# pytorch_dataset/jincheng60.png
# pytorch_dataset/mahmuda60.png
# pytorch_dataset/numan60.png
# pytorch_dataset/saseendran60.png
# pytorch_dataset/afiq61.png
# pytorch_dataset/azureen61.png
# pytorch_dataset/gavin61.png
# pytorch_dataset/goke61.png
# pytorch_dataset/inamul61.png
# pytorch_dataset/jincheng61.png
# pytorch_dataset/mahmuda61.png
# pytorch_dataset/numan61.png
# pytorch_dataset/saseendran61.png
# pytorch_dataset/azureen62.png
# pytorch_dataset/gavin62.png
# pytorch_dataset/goke62.png
# pytorch_dataset/mahmuda62.png
# pytorch_dataset/numan62.png
# pytorch_dataset/azureen63.png
# pytorch_dataset/gavin63.png
# pytorch_dataset/goke63.png
# pytorch_dataset/mahmuda63.png
# pytorch_dataset/numan63.png

# %%
a = np.array(imageNameList)
b = np.array(labelList)

# %%
a = np.reshape(a,(-1,1))
b = np.reshape(b,(-1,1))

# %%
stacked = np.hstack((a,b))
stacked
# Out:
# array([['afiq1.png', '0'],
#        ['azureen1.png', '1'],
#        ['gavin1.png', '2'],
#        ['goke1.png', '3'],
#        ['inamul1.png', '4'],
#        ['jincheng1.png', '5'],
#        ['mahmuda1.png', '6'],
#        ['numan1.png', '7'],
#        ['saseendran1.png', '8'],
#        ['afiq2.png', '0'],
#        ['azureen2.png', '1'],
#        ['goke2.png', '3'],
#        ['numan2.png', '7'],
#        ['afiq3.png', '0'],
#        ['azureen3.png', '1'],
#        ['goke3.png', '3'],
#        ['numan3.png', '7'],
#        ['afiq4.png', '0'],
#        ['azureen4.png', '1'],
#        ['goke4.png', '3'],
#        ['inamul4.png', '4'],
#        ['mahmuda4.png', '6'],
#        ['numan4.png', '7'],
#        ['saseendran4.png', '8'],
#        ['afiq5.png', '0'],
#        ['azureen5.png', '1'],
#        ['goke5.png', '3'],
#        ['inamul5.png', '4'],
#        ['mahmuda5.png', '6'],
#        ['numan5.png', '7'],
#        ['saseendran5.png', '8'],
#        ['afiq6.png', '0'],
#        ['azureen6.png', '1'],
#        ['gavin6.png', '2'],
#        ['goke6.png', '3'],
#        ['mahmuda6.png', '6'],
#        ['numan6.png', '7'],
#        ['saseendran6.png', '8'],
#        ['afiq7.png', '0'],
#        ['azureen7.png', '1'],
#        ['gavin7.png', '2'],
#        ['goke7.png', '3'],
#        ['inamul7.png', '4'],
#        ['jincheng7.png', '5'],
#        ['mahmuda7.png', '6'],
#        ['numan7.png', '7'],
#        ['saseendran7.png', '8'],
#        ['afiq8.png', '0'],
#        ['azureen8.png', '1'],
#        ['goke8.png', '3'],
#        ['inamul8.png', '4'],
#        ['mahmuda8.png', '6'],
#        ['numan8.png', '7'],
#        ['azureen9.png', '1'],
#        ['gavin9.png', '2'],
#        ['goke9.png', '3'],
#        ['mahmuda9.png', '6'],
#        ['numan9.png', '7'],
#        ['afiq10.png', '0'],
#        ['azureen10.png', '1'],
#        ['goke10.png', '3'],
#        ['inamul10.png', '4'],
#        ['mahmuda10.png', '6'],
#        ['numan10.png', '7'],
#        ['azureen11.png', '1'],
#        ['gavin11.png', '2'],
#        ['goke11.png', '3'],
#        ['mahmuda11.png', '6'],
#        ['numan11.png', '7'],
#        ['saseendran11.png', '8'],
#        ['afiq12.png', '0'],
#        ['azureen12.png', '1'],
#        ['gavin12.png', '2'],
#        ['goke12.png', '3'],
#        ['inamul12.png', '4'],
#        ['jincheng12.png', '5'],
#        ['mahmuda12.png', '6'],
#        ['numan12.png', '7'],
#        ['saseendran12.png', '8'],
#        ['gavin13.png', '2'],
#        ['goke13.png', '3'],
#        ['mahmuda13.png', '6'],
#        ['numan13.png', '7'],
#        ['saseendran13.png', '8'],
#        ['afiq14.png', '0'],
#        ['azureen14.png', '1'],
#        ['goke14.png', '3'],
#        ['inamul14.png', '4'],
#        ['numan14.png', '7'],
#        ['azureen15.png', '1'],
#        ['goke15.png', '3'],
#        ['jincheng15.png', '5'],
#        ['mahmuda15.png', '6'],
#        ['saseendran15.png', '8'],
#        ['azureen16.png', '1'],
#        ['gavin16.png', '2'],
#        ['goke16.png', '3'],
#        ['mahmuda16.png', '6'],
#        ['numan16.png', '7'],
#        ['azureen17.png', '1'],
#        ['gavin17.png', '2'],
#        ['inamul17.png', '4'],
#        ['mahmuda17.png', '6'],
#        ['numan17.png', '7'],
#        ['saseendran17.png', '8'],
#        ['azureen18.png', '1'],
#        ['jincheng18.png', '5'],
#        ['azureen19.png', '1'],
#        ['gavin19.png', '2'],
#        ['goke19.png', '3'],
#        ['jincheng19.png', '5'],
#        ['mahmuda19.png', '6'],
#        ['numan19.png', '7'],
#        ['saseendran19.png', '8'],
#        ['azureen20.png', '1'],
#        ['gavin20.png', '2'],
#        ['inamul20.png', '4'],
#        ['saseendran20.png', '8'],
#        ['azureen21.png', '1'],
#        ['gavin21.png', '2'],
#        ['goke21.png', '3'],
#        ['inamul21.png', '4'],
#        ['jincheng21.png', '5'],
#        ['numan21.png', '7'],
#        ['saseendran21.png', '8'],
#        ['azureen22.png', '1'],
#        ['gavin22.png', '2'],
#        ['goke22.png', '3'],
#        ['inamul22.png', '4'],
#        ['mahmuda22.png', '6'],
#        ['numan22.png', '7'],
#        ['saseendran22.png', '8'],
#        ['afiq23.png', '0'],
#        ['azureen23.png', '1'],
#        ['gavin23.png', '2'],
#        ['goke23.png', '3'],
#        ['inamul23.png', '4'],
#        ['jincheng23.png', '5'],
#        ['mahmuda23.png', '6'],
#        ['numan23.png', '7'],
#        ['saseendran23.png', '8'],
#        ['azureen24.png', '1'],
#        ['gavin24.png', '2'],
#        ['goke24.png', '3'],
#        ['mahmuda24.png', '6'],
#        ['numan24.png', '7'],
#        ['afiq25.png', '0'],
#        ['azureen25.png', '1'],
#        ['mahmuda25.png', '6'],
#        ['afiq26.png', '0'],
#        ['azureen26.png', '1'],
#        ['gavin26.png', '2'],
#        ['goke26.png', '3'],
#        ['inamul26.png', '4'],
#        ['jincheng26.png', '5'],
#        ['mahmuda26.png', '6'],
#        ['numan26.png', '7'],
#        ['saseendran26.png', '8'],
#        ['afiq27.png', '0'],
#        ['azureen27.png', '1'],
#        ['gavin27.png', '2'],
#        ['goke27.png', '3'],
#        ['inamul27.png', '4'],
#        ['jincheng27.png', '5'],
#        ['mahmuda27.png', '6'],
#        ['numan27.png', '7'],
#        ['saseendran27.png', '8'],
#        ['afiq28.png', '0'],
#        ['azureen28.png', '1'],
#        ['gavin28.png', '2'],
#        ['inamul28.png', '4'],
#        ['jincheng28.png', '5'],
#        ['mahmuda28.png', '6'],
#        ['numan28.png', '7'],
#        ['saseendran28.png', '8'],
#        ['afiq29.png', '0'],
#        ['azureen29.png', '1'],
#        ['gavin29.png', '2'],
#        ['goke29.png', '3'],
#        ['inamul29.png', '4'],
#        ['jincheng29.png', '5'],
#        ['mahmuda29.png', '6'],
#        ['numan29.png', '7'],
#        ['saseendran29.png', '8'],
#        ['afiq30.png', '0'],
#        ['azureen30.png', '1'],
#        ['mahmuda30.png', '6'],
#        ['afiq31.png', '0'],
#        ['azureen31.png', '1'],
#        ['gavin31.png', '2'],
#        ['goke31.png', '3'],
#        ['inamul31.png', '4'],
#        ['jincheng31.png', '5'],
#        ['mahmuda31.png', '6'],
#        ['numan31.png', '7'],
#        ['saseendran31.png', '8'],
#        ['afiq32.png', '0'],
#        ['azureen32.png', '1'],
#        ['gavin32.png', '2'],
#        ['goke32.png', '3'],
#        ['inamul32.png', '4'],
#        ['jincheng32.png', '5'],
#        ['mahmuda32.png', '6'],
#        ['numan32.png', '7'],
#        ['saseendran32.png', '8'],
#        ['afiq33.png', '0'],
#        ['azureen33.png', '1'],
#        ['gavin33.png', '2'],
#        ['goke33.png', '3'],
#        ['inamul33.png', '4'],
#        ['mahmuda33.png', '6'],
#        ['numan33.png', '7'],
#        ['afiq34.png', '0'],
#        ['azureen34.png', '1'],
#        ['gavin34.png', '2'],
#        ['goke34.png', '3'],
#        ['inamul34.png', '4'],
#        ['jincheng34.png', '5'],
#        ['mahmuda34.png', '6'],
#        ['numan34.png', '7'],
#        ['saseendran34.png', '8'],
#        ['afiq35.png', '0'],
#        ['gavin35.png', '2'],
#        ['goke35.png', '3'],
#        ['saseendran35.png', '8'],
#        ['afiq36.png', '0'],
#        ['azureen36.png', '1'],
#        ['gavin36.png', '2'],
#        ['goke36.png', '3'],
#        ['inamul36.png', '4'],
#        ['jincheng36.png', '5'],
#        ['mahmuda36.png', '6'],
#        ['numan36.png', '7'],
#        ['saseendran36.png', '8'],
#        ['afiq37.png', '0'],
#        ['azureen37.png', '1'],
#        ['gavin37.png', '2'],
#        ['goke37.png', '3'],
#        ['mahmuda37.png', '6'],
#        ['numan37.png', '7'],
#        ['saseendran37.png', '8'],
#        ['afiq38.png', '0'],
#        ['azureen38.png', '1'],
#        ['gavin38.png', '2'],
#        ['goke38.png', '3'],
#        ['mahmuda38.png', '6'],
#        ['numan38.png', '7'],
#        ['saseendran38.png', '8'],
#        ['afiq39.png', '0'],
#        ['azureen39.png', '1'],
#        ['gavin39.png', '2'],
#        ['goke39.png', '3'],
#        ['mahmuda39.png', '6'],
#        ['numan39.png', '7'],
#        ['saseendran39.png', '8'],
#        ['afiq40.png', '0'],
#        ['azureen40.png', '1'],
#        ['gavin40.png', '2'],
#        ['goke40.png', '3'],
#        ['mahmuda40.png', '6'],
#        ['numan40.png', '7'],
#        ['saseendran40.png', '8'],
#        ['afiq41.png', '0'],
#        ['azureen41.png', '1'],
#        ['gavin41.png', '2'],
#        ['goke41.png', '3'],
#        ['mahmuda41.png', '6'],
#        ['numan41.png', '7'],
#        ['saseendran41.png', '8'],
#        ['afiq42.png', '0'],
#        ['azureen42.png', '1'],
#        ['gavin42.png', '2'],
#        ['goke42.png', '3'],
#        ['goke42.png', '3'],
#        ['mahmuda42.png', '6'],
#        ['numan42.png', '7'],
#        ['saseendran42.png', '8'],
#        ['afiq43.png', '0'],
#        ['azureen43.png', '1'],
#        ['gavin43.png', '2'],
#        ['goke43.png', '3'],
#        ['mahmuda43.png', '6'],
#        ['numan43.png', '7'],
#        ['saseendran43.png', '8'],
#        ['afiq44.png', '0'],
#        ['azureen44.png', '1'],
#        ['gavin44.png', '2'],
#        ['goke44.png', '3'],
#        ['mahmuda44.png', '6'],
#        ['numan44.png', '7'],
#        ['saseendran44.png', '8'],
#        ['afiq45.png', '0'],
#        ['azureen45.png', '1'],
#        ['goke45.png', '3'],
#        ['jincheng45.png', '5'],
#        ['mahmuda45.png', '6'],
#        ['numan45.png', '7'],
#        ['saseendran45.png', '8'],
#        ['afiq46.png', '0'],
#        ['azureen46.png', '1'],
#        ['gavin46.png', '2'],
#        ['goke46.png', '3'],
#        ['inamul46.png', '4'],
#        ['jincheng46.png', '5'],
#        ['mahmuda46.png', '6'],
#        ['numan46.png', '7'],
#        ['saseendran46.png', '8'],
#        ['afiq47.png', '0'],
#        ['azureen47.png', '1'],
#        ['goke47.png', '3'],
#        ['inamul47.png', '4'],
#        ['mahmuda47.png', '6'],
#        ['numan47.png', '7'],
#        ['afiq48.png', '0'],
#        ['azureen48.png', '1'],
#        ['gavin48.png', '2'],
#        ['goke48.png', '3'],
#        ['inamul48.png', '4'],
#        ['jincheng48.png', '5'],
#        ['mahmuda48.png', '6'],
#        ['numan48.png', '7'],
#        ['saseendran48.png', '8'],
#        ['afiq49.png', '0'],
#        ['azureen49.png', '1'],
#        ['gavin49.png', '2'],
#        ['goke49.png', '3'],
#        ['inamul49.png', '4'],
#        ['jincheng49.png', '5'],
#        ['mahmuda49.png', '6'],
#        ['numan49.png', '7'],
#        ['saseendran49.png', '8'],
#        ['afiq50.png', '0'],
#        ['azureen50.png', '1'],
#        ['goke50.png', '3'],
#        ['inamul50.png', '4'],
#        ['mahmuda50.png', '6'],
#        ['numan50.png', '7'],
#        ['afiq51.png', '0'],
#        ['azureen51.png', '1'],
#        ['gavin51.png', '2'],
#        ['goke51.png', '3'],
#        ['inamul51.png', '4'],
#        ['jincheng51.png', '5'],
#        ['mahmuda51.png', '6'],
#        ['numan51.png', '7'],
#        ['saseendran51.png', '8'],
#        ['azureen52.png', '1'],
#        ['gavin52.png', '2'],
#        ['inamul52.png', '4'],
#        ['mahmuda52.png', '6'],
#        ['numan52.png', '7'],
#        ['saseendran52.png', '8'],
#        ['azureen53.png', '1'],
#        ['gavin53.png', '2'],
#        ['goke53.png', '3'],
#        ['inamul53.png', '4'],
#        ['jincheng53.png', '5'],
#        ['mahmuda53.png', '6'],
#        ['numan53.png', '7'],
#        ['afiq54.png', '0'],
#        ['azureen54.png', '1'],
#        ['inamul54.png', '4'],
#        ['jincheng54.png', '5'],
#        ['mahmuda54.png', '6'],
#        ['numan54.png', '7'],
#        ['saseendran54.png', '8'],
#        ['azureen55.png', '1'],
#        ['gavin55.png', '2'],
#        ['goke55.png', '3'],
#        ['mahmuda55.png', '6'],
#        ['numan55.png', '7'],
#        ['afiq56.png', '0'],
#        ['azureen56.png', '1'],
#        ['gavin56.png', '2'],
#        ['goke56.png', '3'],
#        ['inamul56.png', '4'],
#        ['jincheng56.png', '5'],
#        ['mahmuda56.png', '6'],
#        ['numan56.png', '7'],
#        ['saseendran56.png', '8'],
#        ['afiq57.png', '0'],
#        ['azureen57.png', '1'],
#        ['gavin57.png', '2'],
#        ['goke57.png', '3'],
#        ['inamul57.png', '4'],
#        ['jincheng57.png', '5'],
#        ['mahmuda57.png', '6'],
#        ['numan57.png', '7'],
#        ['saseendran57.png', '8'],
#        ['afiq58.png', '0'],
#        ['azureen58.png', '1'],
#        ['gavin58.png', '2'],
#        ['goke58.png', '3'],
#        ['inamul58.png', '4'],
#        ['jincheng58.png', '5'],
#        ['mahmuda58.png', '6'],
#        ['numan58.png', '7'],
#        ['saseendran58.png', '8'],
#        ['afiq59.png', '0'],
#        ['azureen59.png', '1'],
#        ['gavin59.png', '2'],
#        ['goke59.png', '3'],
#        ['inamul59.png', '4'],
#        ['jincheng59.png', '5'],
#        ['mahmuda59.png', '6'],
#        ['saseendran59.png', '8'],
#        ['afiq60.png', '0'],
#        ['azureen60.png', '1'],
#        ['gavin60.png', '2'],
#        ['goke60.png', '3'],
#        ['inamul60.png', '4'],
#        ['jincheng60.png', '5'],
#        ['mahmuda60.png', '6'],
#        ['numan60.png', '7'],
#        ['saseendran60.png', '8'],
#        ['afiq61.png', '0'],
#        ['azureen61.png', '1'],
#        ['gavin61.png', '2'],
#        ['goke61.png', '3'],
#        ['inamul61.png', '4'],
#        ['jincheng61.png', '5'],
#        ['mahmuda61.png', '6'],
#        ['numan61.png', '7'],
#        ['saseendran61.png', '8'],
#        ['azureen62.png', '1'],
#        ['gavin62.png', '2'],
#        ['goke62.png', '3'],
#        ['mahmuda62.png', '6'],
#        ['numan62.png', '7'],
#        ['azureen63.png', '1'],
#        ['gavin63.png', '2'],
#        ['goke63.png', '3'],
#        ['mahmuda63.png', '6'],
#        ['numan63.png', '7']], dtype='<U16')

# %%
# save image with label to csv
import pandas as pd
df = pd.DataFrame(stacked)
df.to_csv('pytorch_dataset/pytorch_dataset.csv',index = False,header=None)
